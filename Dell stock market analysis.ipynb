# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\stock price dell datasets.csv")

# %%
data
# Out:
#                            Date       Open       High        Low      Close  \
# 0     2016-08-17 00:00:00-04:00  11.636467  11.770219  11.502714  11.502714
# 1     2016-08-18 00:00:00-04:00  11.770218  11.770218  11.368961  11.435837
# 2     2016-08-19 00:00:00-04:00  11.422462  11.636466  11.409087  11.636466
# 3     2016-08-22 00:00:00-04:00  11.502714  12.198227  11.395712  11.676593
# 4     2016-08-23 00:00:00-04:00  11.703343  12.278478  11.636466  12.037724
# ...                         ...        ...        ...        ...        ...
# 1094  2020-12-21 00:00:00-05:00  34.938801  35.431581  34.315587  35.296307
# 1095  2020-12-22 00:00:00-05:00  35.605493  35.687622  35.049914  35.136871
# 1096  2020-12-23 00:00:00-05:00  35.219010  35.677967  34.972620  35.460564
# 1097  2020-12-24 00:00:00-05:00  35.634485  35.697291  35.146541  35.262489
# 1098  2020-12-28 00:00:00-05:00  35.533031  35.629653  34.996774  35.194851
#
#        Volume  Dividends  Stock Splits
# ...

# %%
data = data.drop(['Dividends','Stock Splits'] , axis = 1)

# %%
data
# Out:
#                            Date       Open       High        Low      Close  \
# 0     2016-08-17 00:00:00-04:00  11.636467  11.770219  11.502714  11.502714
# 1     2016-08-18 00:00:00-04:00  11.770218  11.770218  11.368961  11.435837
# 2     2016-08-19 00:00:00-04:00  11.422462  11.636466  11.409087  11.636466
# 3     2016-08-22 00:00:00-04:00  11.502714  12.198227  11.395712  11.676593
# 4     2016-08-23 00:00:00-04:00  11.703343  12.278478  11.636466  12.037724
# ...                         ...        ...        ...        ...        ...
# 1094  2020-12-21 00:00:00-05:00  34.938801  35.431581  34.315587  35.296307
# 1095  2020-12-22 00:00:00-05:00  35.605493  35.687622  35.049914  35.136871
# 1096  2020-12-23 00:00:00-05:00  35.219010  35.677967  34.972620  35.460564
# 1097  2020-12-24 00:00:00-05:00  35.634485  35.697291  35.146541  35.262489
# 1098  2020-12-28 00:00:00-05:00  35.533031  35.629653  34.996774  35.194851
#
#        Volume
# 0      271519
# 1     1767366
# ...

# %%
data.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
data.duplicated().any()
# Out:
# False

# %%
data.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1099.000000  1099.000000  1099.000000  1099.000000  1.099000e+03
# mean     22.746190    23.028133    22.453843    22.749399  6.073928e+06
# std       5.505747     5.554388     5.427301     5.495255  7.803616e+06
# min      11.422462    11.636466    11.240558    11.435837  2.234150e+05
# 25%      18.316065    18.694584    18.138173    18.435106  3.224196e+06
# 50%      23.068692    23.361207    22.684418    22.994726  4.520538e+06
# 75%      25.996133    26.240335    25.678990    25.964957  6.386404e+06
# max      36.233550    36.421963    35.813235    36.093445  1.479072e+08

# %%
data.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21376\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             Open      High       Low     Close    Volume
# Open    1.000000  0.998862  0.998293  0.997666 -0.084981
# High    0.998862  1.000000  0.997708  0.998583 -0.076414
# Low     0.998293  0.997708  1.000000  0.998843 -0.105201
# Close   0.997666  0.998583  0.998843  1.000000 -0.093232
# Volume -0.084981 -0.076414 -0.105201 -0.093232  1.000000

# %%
data.kurtosis()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21376\2361870383.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurtosis()
# Open       -0.550081
# High       -0.550982
# Low        -0.542160
# Close      -0.541601
# Volume    159.772220
# dtype: float64

# %%
data.skew()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21376\1188251951.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# Open       0.116875
# High       0.118398
# Low        0.122851
# Close      0.125523
# Volume    10.578137
# dtype: float64

# %%
sn.heatmap(data.corr() , annot = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21376\1853385573.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(data.corr() , annot = True)
# <Axes: >

# %%
sn.distplot(data['Volume'] , color = 'red')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21376\2497131771.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data['Volume'] , color = 'red')
# <Axes: xlabel='Volume', ylabel='Density'>

# %%
data.value_counts()
# Out:
# Date                       Open       High       Low        Close      Volume
# 2016-08-17 00:00:00-04:00  11.636467  11.770219  11.502714  11.502714  271519      1
# 2019-07-15 00:00:00-04:00  26.088153  26.706538  26.063998  26.677553  7950993     1
# 2019-07-23 00:00:00-04:00  27.392560  27.392560  26.397345  26.793499  4539084     1
# 2019-07-22 00:00:00-04:00  27.566481  27.721077  27.242794  27.257288  3269853     1
# 2019-07-19 00:00:00-04:00  27.996453  28.585852  27.344250  27.440872  5908543     1
#                                                                                   ..
# 2018-02-08 00:00:00-05:00  17.858630  18.118109  17.486798  17.553675  12260033    1
# 2018-02-09 00:00:00-05:00  17.802455  18.171612  17.377123  18.003084  9210614     1
# 2018-02-12 00:00:00-05:00  18.077983  18.390963  17.930856  18.198359  8159815     1
# 2018-02-13 00:00:00-05:00  18.056585  18.393641  17.949583  18.270590  6382472     1
# ...

# %%
data = data.set_index('Date')

# %%
data
# Out:
#                                 Open       High        Low      Close   Volume
# Date
# 2016-08-17 00:00:00-04:00  11.636467  11.770219  11.502714  11.502714   271519
# 2016-08-18 00:00:00-04:00  11.770218  11.770218  11.368961  11.435837  1767366
# 2016-08-19 00:00:00-04:00  11.422462  11.636466  11.409087  11.636466  4735900
# 2016-08-22 00:00:00-04:00  11.502714  12.198227  11.395712  11.676593  2245909
# 2016-08-23 00:00:00-04:00  11.703343  12.278478  11.636466  12.037724  1483020
# ...                              ...        ...        ...        ...      ...
# 2020-12-21 00:00:00-05:00  34.938801  35.431581  34.315587  35.296307  3446042
# 2020-12-22 00:00:00-05:00  35.605493  35.687622  35.049914  35.136871  2565492
# 2020-12-23 00:00:00-05:00  35.219010  35.677967  34.972620  35.460564  3252096
# 2020-12-24 00:00:00-05:00  35.634485  35.697291  35.146541  35.262489  3294318
# 2020-12-28 00:00:00-05:00  35.533031  35.629653  34.996774  35.194851  6292884
#
# ...

# %%
plt.figure(figsize = (18,9))
data['Open'].plot(kind = 'line')
# Out:
# <Axes: xlabel='Date'>

# %%
sn.boxplot(data['Volume'])
# Out:
# <Axes: >

# %%
q1 = data['Volume'].quantile(0.25)
q3 = data['Volume'].quantile(0.75)

iqr = q3-q1
upper_bound = q3+1.5*iqr
lower_bound = q1-1.5*iqr

# %%
upper_bound , lower_bound
# Out:
# (11129714.75, -1519115.25)

# %%
data = data[~(data>upper_bound)|(data<lower_bound)]

# %%
data
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2016-08-17 00:00:00-04:00  11.636467  11.770219  11.502714  11.502714
# 2016-08-18 00:00:00-04:00  11.770218  11.770218  11.368961  11.435837
# 2016-08-19 00:00:00-04:00  11.422462  11.636466  11.409087  11.636466
# 2016-08-22 00:00:00-04:00  11.502714  12.198227  11.395712  11.676593
# 2016-08-23 00:00:00-04:00  11.703343  12.278478  11.636466  12.037724
# ...                              ...        ...        ...        ...
# 2020-12-21 00:00:00-05:00  34.938801  35.431581  34.315587  35.296307
# 2020-12-22 00:00:00-05:00  35.605493  35.687622  35.049914  35.136871
# 2020-12-23 00:00:00-05:00  35.219010  35.677967  34.972620  35.460564
# 2020-12-24 00:00:00-05:00  35.634485  35.697291  35.146541  35.262489
# 2020-12-28 00:00:00-05:00  35.533031  35.629653  34.996774  35.194851
#
#                               Volume
# Date
# 2016-08-17 00:00:00-04:00   271519.0
# 2016-08-18 00:00:00-04:00  1767366.0
# ...

# %%
sn.boxplot(data['Volume'])
# Out:
# <Axes: >

# %%
data = data.reset_index()

# %%
data
# Out:
#                            Date       Open       High        Low      Close  \
# 0     2016-08-17 00:00:00-04:00  11.636467  11.770219  11.502714  11.502714
# 1     2016-08-18 00:00:00-04:00  11.770218  11.770218  11.368961  11.435837
# 2     2016-08-19 00:00:00-04:00  11.422462  11.636466  11.409087  11.636466
# 3     2016-08-22 00:00:00-04:00  11.502714  12.198227  11.395712  11.676593
# 4     2016-08-23 00:00:00-04:00  11.703343  12.278478  11.636466  12.037724
# ...                         ...        ...        ...        ...        ...
# 1094  2020-12-21 00:00:00-05:00  34.938801  35.431581  34.315587  35.296307
# 1095  2020-12-22 00:00:00-05:00  35.605493  35.687622  35.049914  35.136871
# 1096  2020-12-23 00:00:00-05:00  35.219010  35.677967  34.972620  35.460564
# 1097  2020-12-24 00:00:00-05:00  35.634485  35.697291  35.146541  35.262489
# 1098  2020-12-28 00:00:00-05:00  35.533031  35.629653  34.996774  35.194851
#
#          Volume
# 0      271519.0
# 1     1767366.0
# ...

# %%
data.isnull().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume    90
# dtype: int64

# %%
data = data.fillna(0)

# %%
data.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
data = data.set_index('Date')

# %%
data
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2016-08-17 00:00:00-04:00  11.636467  11.770219  11.502714  11.502714
# 2016-08-18 00:00:00-04:00  11.770218  11.770218  11.368961  11.435837
# 2016-08-19 00:00:00-04:00  11.422462  11.636466  11.409087  11.636466
# 2016-08-22 00:00:00-04:00  11.502714  12.198227  11.395712  11.676593
# 2016-08-23 00:00:00-04:00  11.703343  12.278478  11.636466  12.037724
# ...                              ...        ...        ...        ...
# 2020-12-21 00:00:00-05:00  34.938801  35.431581  34.315587  35.296307
# 2020-12-22 00:00:00-05:00  35.605493  35.687622  35.049914  35.136871
# 2020-12-23 00:00:00-05:00  35.219010  35.677967  34.972620  35.460564
# 2020-12-24 00:00:00-05:00  35.634485  35.697291  35.146541  35.262489
# 2020-12-28 00:00:00-05:00  35.533031  35.629653  34.996774  35.194851
#
#                               Volume
# Date
# 2016-08-17 00:00:00-04:00   271519.0
# 2016-08-18 00:00:00-04:00  1767366.0
# ...

# %%
 def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return(x)

# %%
data = norm_func(data)

# %%
data
# Out:
#                                Open      High       Low     Close    Volume
# Date
# 2016-08-17 00:00:00-04:00  0.008625  0.005396  0.010669  0.002712  0.024421
# 2016-08-18 00:00:00-04:00  0.014016  0.005396  0.005225  0.000000  0.158959
# 2016-08-19 00:00:00-04:00  0.000000  0.000000  0.006858  0.008137  0.425953
# 2016-08-22 00:00:00-04:00  0.003235  0.022665  0.006314  0.009764  0.202000
# 2016-08-23 00:00:00-04:00  0.011321  0.025903  0.016112  0.024410  0.133385
# ...                             ...       ...       ...       ...       ...
# 2020-12-21 00:00:00-05:00  0.947816  0.960042  0.939052  0.967672  0.309941
# 2020-12-22 00:00:00-05:00  0.974686  0.970372  0.968936  0.961206  0.230743
# 2020-12-23 00:00:00-05:00  0.959109  0.969983  0.965791  0.974333  0.292497
# 2020-12-24 00:00:00-05:00  0.975855  0.970762  0.972868  0.966300  0.296295
# 2020-12-28 00:00:00-05:00  0.971766  0.968033  0.966774  0.963557  0.565990
#
# [1099 rows x 5 columns]

# %%
sn.distplot(data['Volume'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21376\2812699079.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data['Volume'])
# <Axes: xlabel='Volume', ylabel='Density'>

# %%
sn.pairplot(data)

# %%
data.shape
# Out:
# (1099, 5)

# %%
x = data.drop(['Open'] , axis = 1)
y = data['Open']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.20 , random_state = 42)

# %%
x_train.shape , x_test.shape
# Out:
# ((879, 4), (220, 4))

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
model_pred = model.predict(x_test)

# %%
model_pred
# Out:
# array([0.55752259, 0.7904018 , 0.48085584, 0.42357399, 0.33032491,
#        0.61168983, 0.06689699, 0.41403771, 0.44661796, 0.87134748,
#        0.94129289, 0.89088857, 0.3475028 , 0.9209683 , 0.22349808,
#        0.54093548, 0.05397246, 0.26367843, 0.59523692, 0.32302946,
#        0.39137078, 0.53074134, 0.39269689, 0.22940781, 0.98703935,
#        0.33523384, 0.36408697, 0.4169451 , 0.34394366, 0.75554715,
#        0.76891835, 0.46751156, 0.23754949, 0.54008101, 0.50774098,
#        0.22131978, 0.65287883, 0.49843523, 0.46192974, 0.17386147,
#        0.80573285, 0.58076126, 0.55148548, 0.09633799, 0.49273937,
#        0.57887496, 0.7032123 , 0.41327791, 0.68059794, 0.55985807,
#        0.06079991, 0.57457956, 0.50789125, 0.20676024, 0.4850073 ,
#        0.78465019, 0.17514141, 0.51516911, 0.25607816, 0.53927223,
#        0.50751127, 0.57388924, 0.42261321, 0.40063191, 0.36991006,
#        0.05444797, 0.40831092, 0.2077784 , 0.14477965, 0.84774433,
# ...

# %%
pd.DataFrame({'Actual':y_test , 'Predicted': model_pred})
# Out:
#                              Actual  Predicted
# Date
# 2018-10-22 00:00:00-04:00  0.555579   0.557523
# 2020-09-21 00:00:00-04:00  0.800804   0.790402
# 2018-06-12 00:00:00-04:00  0.484528   0.480856
# 2019-01-11 00:00:00-05:00  0.414875   0.423574
# 2018-04-24 00:00:00-04:00  0.330889   0.330325
# ...                             ...        ...
# 2020-04-22 00:00:00-04:00  0.285389   0.288845
# 2019-11-21 00:00:00-05:00  0.615239   0.614490
# 2019-09-27 00:00:00-04:00  0.560329   0.554362
# 2018-10-10 00:00:00-04:00  0.560862   0.553332
# 2017-10-05 00:00:00-04:00  0.385984   0.385777
#
# [220 rows x 2 columns]

# %%
mse = np.mean((y_test-model_pred)**2)

# %%
mse
# Out:
# 4.536767984859025e-05

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.006735553418137982

# %%
pred = np.array([[0.99 , 0.67 , 0.89 , 0.65]])

# %%
model.predict(pred)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.83142343])
